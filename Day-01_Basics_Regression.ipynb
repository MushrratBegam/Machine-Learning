# %%
import numpy as np

# %%
experience = np.array([1,2,3,4,5,6,7])

# %%
salary = np.array([25,30,35,40,45,50])

# %%
# Regration 
# y = mx + c
# y = output
# x = input
# m = cooficient   (slope)   = 5
# c = intecept (straighting point) = 20

# %%
# patterns / rule (learned by computer)
m = 5
c = 20

# %%
x = 9
print("Pridicted Salary :",m*x+c)
# Out:
# Pridicted Salary : 65
